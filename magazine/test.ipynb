# %%
import pandas as pd
df_test=pd.read_csv('test1.csv')
df_test.head(15)
# Out:
#                     Movie_title                    Movie_type  \
# 0                      The Toll              Horror, Thriller
# 1                       Spencer     Biography, Drama, Romance
# 2                    200 Meters              Adventure, Drama
# 3                      Unhinged              ACTION, THRILLER
# 4                       Antlers        Drama, Horror, Mystery
# 5            Last Night in Soho        Drama, Horror, Mystery
# 6              Monster Family 2             Animation, Comedy
# 7               Halloween Kills              Horror, Thriller
# 8              Ron's Gone Wrong  Animation, Adventure, Comedy
# 9   Venom: Let There Be Carnage     Action, Adventure, Sci-Fi
# 10                 Honest Thief              Horror, Thriller
# 11               No Time to Die     Biography, Drama, Romance
# 12          The Addams Family 2              Adventure, Drama
# 13                 الإنس والنمس              ACTION, THRILLER
# ...
